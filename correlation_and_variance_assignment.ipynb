# %% [markdown]
# Q1)  Define Covariance and explain how it differs from Correlation in terms of scale and interpretation.
#
# ans?) Covariance:
#
# Definition: Covariance measures how two random variables change together.
#
# If both variables tend to increase or decrease simultaneously, the covariance is positive.
#
# If one increases while the other decreases, the covariance is negative.
#
# If they are independent, the covariance is close to zero.
#
# Formula:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# ) = ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ) /n-1
#
# Scale:
#
#  Covariance is expressed in the product of the units of the two variables (e.g., cm·kg). This makes it scale-dependent and hard to interpret directly.
#
#  Correlation:
#
#
# Definition: Correlation is a standardized measure of the strength and direction of the linear relationship between two variables. It is essentially the normalized version of covariance.
#
# Formula:
#
# 𝜌
# 𝑋
# ,
# 𝑌 = Cov
# (
# 𝑋
# ,
# 𝑌
# ) / 𝜎
# 𝑋
# ⋅
# 𝜎
# 𝑌
#
# Scale:
#
#  Correlation is unitless and always lies between -1 and +1.
#
# +1 → perfect positive linear relationship
#
# -1 → perfect negative linear relationship
#
# 0 → no linear relationship.
#
# The key difference between covariance and correlation lies in their scale and interpretability.
#
#  Covariance measures the degree to which two variables move together, but its value is dependent on the units of the variables, making it scale-dependent and often difficult to interpret directly.
#
#   For example, the covariance between height (in centimeters) and weight (in kilograms) would be expressed in cm·kg, which doesn’t provide a standardized sense of strength.
#
#    Correlation, on the other hand, is a normalized version of covariance that removes the influence of scale by dividing by the product of the standard deviations of the two variables.
#
#    In essence, covariance tells you whether variables move together, while correlation tells you how strongly and consistently they do so across different scales.

# %% [markdown]
# Q2) What does a positive, negative, and zero covariance indicate about the relationship between two variables?
#
# ans)Positive Covariance:
#
# Meaning: When covariance is positive, it indicates that the two variables tend to move in the same direction.
#
# If one increases, the other also tends to increase.
#
# If one decreases, the other also tends to decrease.
#
# Example: Height and weight often show positive covariance—taller people generally weigh more.
#
# Negative Covariance:
#
# Meaning: A negative covariance means the two variables move in opposite directions.
#
# If one increases, the other tends to decrease.
#
# If one decreases, the other tends to increase.
#
# Example: Speed of a car and travel time for a fixed distance—higher speed reduces travel time.
#
# Zero Covariance:
#
# Meaning: Zero covariance suggests no linear relationship between the variables.
#
# The variables do not show a consistent pattern of moving together.
#
# Example: Shoe size and exam scores—there’s no meaningful relationship, so covariance is close to zero.
#
# Positive covariance → variables rise and fall together.
#
# Negative covariance → one rises while the other falls.
#
# Zero covariance → no linear relationship at all.

# %% [markdown]
# Q3) Discuss the limitations of covariance as a measure of relationship between two variables. Why is correlation
# preferred in many cases?
#
# ans) Limitations of Covariance:
#
# 1) Scale Dependence:
#
# Covariance values depend on the units of the variables. For example, the covariance between height (in cm) and weight (in kg) will be expressed in cm·kg.
#
# This makes it difficult to compare relationships across datasets with different scales.
#
# 2) Unbounded Values:
#
# Covariance can take any real number, positive or negative, with no fixed range.
#
# Large values don’t necessarily mean a stronger relationship—they may simply reflect larger measurement scales.
#
# 3) Interpretation Difficulty:
#
# While the sign of covariance (positive or negative) indicates the direction of the relationship, the magnitude is not easily interpretable.
#
# A covariance of 200 vs. 2000 doesn’t clearly tell us how strong the relationship is without considering the scale of the data.
#
# 4) Not Standardized:
#
# Because covariance is not normalized, it cannot be directly compared across different datasets or variables.
#
# This limits its usefulness in practical analysis where comparisons are needed.
#
# Why Correlation is Preferred:
#
#
# Standardization:
#
#  Correlation normalizes covariance by dividing it by the product of the standard deviations of the two variables.
#
# Unitless Measure:
#
#  It removes the influence of measurement units, making results universally interpretable.
#
# Bounded Range:
#
#  Correlation always lies between -1 and +1, providing a clear scale for strength and direction.
#
# Comparability:
#
#  Because it is standardized, correlation allows easy comparison of relationships across different datasets or contexts.
#
# Interpretability:
#
#  A correlation of +0.8 immediately conveys a strong positive linear relationship, while -0.2 suggests a weak negative one.

# %% [markdown]
# Q4)  Explain the difference between Pearson’s correlation coefficient and Spearman’s rank correlation
# coefficient. When would you prefer to use Spearman’s correlation?
#
# ans)Pearson’s Correlation Coefficient:
#
#
# Definition: Pearson’s correlation measures the strength and direction of the linear relationship between two continuous variables.
#
# Calculation: It is based on the covariance of the variables, normalized by their standard deviations.
#
# Assumptions:
#
# Variables should be normally distributed (or approximately so).
#
# Relationship must be linear.
#
# Sensitive to outliers, which can distort the correlation value.
#
# Range: Between -1 and +1, where values close to ±1 indicate strong linear relationships.
#
# Spearman’s Rank Correlation Coefficient:
#
#
# Definition: Spearman’s correlation measures the strength and direction of the monotonic relationship between two variables, based on the rank order of the data rather than raw values.
#
# Calculation: It converts data into ranks and then applies Pearson’s formula to those ranks.
#
# Assumptions:
#
# Does not require linearity or normal distribution.
#
# Less sensitive to outliers because it uses ranks.
#
# Range: Also between -1 and +1, but interprets monotonic (consistently increasing or decreasing) relationships rather than strictly linear ones.
#
# Pearson’s correlation measures the strength of a linear relationship using raw values, while Spearman’s correlation measures the strength of a monotonic relationship using ranked data.
#
#  Pearson is sensitive to outliers and assumes normality and linearity, whereas Spearman is more robust, works with ordinal data, and does not require strict assumptions.
#
#   In practice, Pearson is used when data are continuous and linear, while Spearman is preferred for non-linear trends, ranked variables, or when outliers are present.
#
#   When to Prefer Spearman’s Correlation:
#
#
# When the relationship between variables is monotonic but not linear (e.g., exponential growth, logarithmic trends).
#
# When data are ordinal (ranked categories rather than continuous values).
#
# When the dataset contains outliers that could distort Pearson’s correlation.
#
# When variables do not meet the assumptions of normality or linearity.

# %% [markdown]
# Q5)  If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you
# infer causation from this value? Why or why not?
#
# ans)A correlation coefficient of 0.85 between two variables
# 𝑋
#  and
# 𝑌
#  indicates a strong positive linear relationship. This means that as values of
# 𝑋
#  increase, values of
# 𝑌
#  also tend to increase, and vice versa. The closeness of the coefficient to +1 suggests that the relationship is not only positive but also quite consistent—points on a scatter plot of
# 𝑋
#  and
# 𝑌
#  would lie close to a straight upward-sloping line.
#
# However, it is important to note that correlation does not imply causation. A high correlation simply shows that two variables move together, but it does not prove that changes in one variable directly cause changes in the other. There could be other explanations, such as:
#
# Confounding variables: A third factor may be influencing both
# 𝑋
#  and
# 𝑌
# .
#
# Reverse causality: It may be that
# 𝑌
#  influences
# 𝑋
# , rather than the other way around.
#
# Coincidence: Sometimes variables can appear correlated due to chance or spurious relationships.

# %% [markdown]
# Q6)Using the dataset below, calculate the covariance between X and Y.
# X
#
# 2
#
# 4
#
# 6
#
# 8
#
# Y
#
# 3
#
# 7
#
# 5
#
# 10
#
# ans) The covariance between X and Y for the given dataset is 4.75, which indicates a positive relationship—when X increases, Y tends to increase as well.
#
# Step-by-Step Calculation
# 1. Dataset:
#
#   X=[
# 2
# ,
# 4
# ,
# 6
# ,
# 8
# ]
#
#   Y=[
# 3
# ,
# 7
# ,
# 5
# ,
# 10
# ]
#
# 2. Mean:
#
# X=2+4+6+8/4=5
#
# Y=3+7+5+10/4=6.25
#
# 3. Deviations:
#
# for X=
# [
# −
# 3
# ,
# −
# 1
# ,
# 1
# ,
# 3
# ]
#
# for Y=[
# −
# 3.25
# ,
# 0.75
# ,
# −
# 1.25
# ,
# 3.75
# ]
#
# 4. Products of Deviations:
#
# (
# −
# 3
# )
# (
# −
# 3.25
# )=9.75
#
# (
# −
# 1
# )
# (
# 0.75
# )=-0.75
#
# (
# 1
# )
# (
# −
# 1.25
# )=-1.25
#
# (
# 3
# )
# (
# 3.75
# )=11.25
#
#
# 5. Covariance Formula:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )=∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# ) / N
#
# For population covariance (
# 𝑛=4):
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )=19/4=4.75
#
# Interpretation:
#
#
# Positive covariance (4.75) → As
# 𝑋
#  increases,
# 𝑌
#  generally increases too.
#
# The magnitude itself is scale-dependent (in units of X·Y), so it doesn’t directly tell us the strength of the relationship.
#
# To get a standardized measure, we would compute the correlation coefficient, which normalizes covariance and makes it easier to interpret.

# %% [markdown]
# Q7)  Compute the Pearson correlation coefficient between variables A and B:
#
# A
#
# 10
#
# 20
#
# 30
#
# 40
#
# 50
#
# B
#
# 8
#
# 14
#
# 18
#
# 24
#
# 28
#
# ans) The Pearson correlation coefficient between A and B is approximately 0.9976, indicating an extremely strong positive linear relationship. This means that as A increases, B also increases in a nearly perfect linear fashion.
#
# tep-by-Step Breakdown
# 1. Dataset:
#
# A=[
# 10
# ,
# 20
# ,
# 30
# ,
# 40
# ,
# 50
# ]
#
# B=[
# 8
# ,
# 14
# ,
# 18
# ,
# 24
# ,
# 28
# ]
#
# 2. Formula:
#
# The Pearson correlation coefficient is given by:
#
# r=Cov
# (
# 𝐴
# ,
# 𝐵
# ) /𝜎
# 𝐴
# ⋅
# 𝜎
# 𝐵
#
# where:
#
# Cov
# (
# 𝐴
# ,
# 𝐵
# )=covariance between A and B
#
# 𝜎
# 𝐴
# ,
# 𝜎
# 𝐵= standard deviations of A and B
#
# 3. Result:
#
#
# Computed correlation coefficient: 0.9976
#
# P-value: 0.0001 (statistically significant)
#
# Interpretation:
#
#
# Strength: The correlation is very close to +1, showing a nearly perfect positive linear relationship.
#
# Direction: Positive correlation → as A increases, B increases.
#
# Statistical Significance: The very low p-value confirms that this relationship is highly unlikely to be due to chance.
#
#  Key Insight:
#
#
# This result shows that variables A and B move together almost perfectly in a linear fashion.
#
# However, correlation does not imply causation. While A and B are strongly related, we cannot conclude that changes in A cause changes in B without further analysis (e.g., experimental or causal modeling).

# %% [markdown]
# Q8)  The following table shows heights (in cm) and weights (in kg) of 5 students.
# Find the correlation coefficient between Height and Weight.
#
# height
#
# 150
#
# 160
#
# 165
#
# 170
#
# 180
#
# weight
#
# 50
#
# 55
#
# 58
#
# 62
#
# 70
#
# ans)The Pearson correlation coefficient between height and weight in this dataset is approximately 0.9922, indicating an extremely strong positive linear relationship. This means taller students tend to weigh more, and the relationship is nearly perfectly linear.
#
# Step-by-Step Calculation
# 1. Dataset:
#
#
# Heights (cm): [150, 160, 165, 170, 180]
#
# Weights (kg): [50, 55, 58, 62, 70]
#
# 2. Formula:
#
#
# The Pearson correlation coefficient is:
#
# r=Cov
# (
# 𝑋
# ,
# 𝑌
# )=𝜎
# 𝑋
# ⋅
# 𝜎
# 𝑌
#
# where:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
#  = covariance between height and weight
#
# 𝜎
# 𝑋
# ,
# 𝜎
# 𝑌= standard deviations of height and weight
#
# 3. Computed Result:
#
#
# Correlation coefficient (r): 0.9922
#
# P-value: 0.0008 (statistically significant)
#
# Interpretation:
#
#
# Strength: The correlation is very close to +1, showing a nearly perfect positive linear relationship.
#
# Direction: Positive correlation → as height increases, weight also increases.
#
# Significance: The very low p-value indicates this relationship is highly unlikely to be due to chance.
#
#  Key Insight:
#
#
# This dataset demonstrates a strong biological trend: taller individuals generally weigh more.
#
# However, correlation does not imply causation. While height and weight are strongly related, other factors (such as body composition, age, or lifestyle) also influence weight.
#
# Final Answer:
#
#  The correlation coefficient between height and weight is 0.9922, showing an almost perfect positive linear relationship.

# %% [markdown]
# Q9)  Given the dataset below, determine whether there is a positive or negative correlation between X and Y.
# (No need for exact calculation, just reasoning.)
#
#
# X
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# Y
#
# 15
#
# 12
#
# 9
#
# 7
#
# 3
#
# ans) Looking at the dataset, as
# 𝑋
#  increases from 1 to 5,
# 𝑌
#  consistently decreases from 15 to 3. This shows that the two variables move in opposite directions: higher values of
# 𝑋
#  are associated with lower values of
# 𝑌
# .
#
# Therefore, the correlation between
# 𝑋
#  and
# 𝑌
#  is negative.
#
# This means there is an inverse relationship—when one variable goes up, the other tends to go down.

# %% [markdown]
# Q10)Two investment portfolios have the following returns (%) over 5 years. Compute the covariance and
# correlation coefficient, and interpret whether the portfolios move together.
#
# year
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5
#
# portfolio A
#
# 8
#
# 10
#
# 12
#
# 9
#
# 11
#
# portfolio B
#
# 6
#
# 9
#
# 11
#
# 8
#
# 10
#
# ans)The covariance between Portfolio A and Portfolio B is 2.40, and the Pearson correlation coefficient is 0.9864. This indicates that the two portfolios move strongly together in the same direction, showing an almost perfect positive linear relationship.
#
# Step-by-Step Results:
#
# 1. Dataset:
#
# Portfolio A returns (%): [8, 10, 12, 9, 11]
#
# Portfolio B returns (%): [6, 9, 11, 8, 10]
#
# 2. Covariance:
#
#
# Covariance = 2.40
#
# Interpretation:
#
#  Positive covariance means that when Portfolio A’s returns increase, Portfolio B’s returns also tend to increase. The magnitude (2.40) is scale-dependent, so it mainly tells us the direction of movement rather than strength.
#
#  3. Correlation:
#
#  Coefficient
# Pearson’s r = 0.9864
#
# Interpretation:
#
# This value is very close to +1, showing an extremely strong positive linear relationship. The portfolios’ returns rise and fall almost in sync.
#
# Interpretation
# Positive Relationship: Both portfolios move together—when one performs well, the other tends to perform well too.
#
# Strength of Relationship: With a correlation of 0.9864, the relationship is nearly perfect. This suggests that diversification benefits between these two portfolios are limited, since they behave very similarly.
#
# Practical Insight: Investors holding both portfolios would not gain much risk reduction, as their returns are highly correlated.
#
# Key Takeaway
# Covariance (2.40) confirms the portfolios move in the same direction.
#
# Correlation (0.9864) shows the relationship is extremely strong and consistent.
#
# Conclusion: The portfolios move almost perfectly together, so combining them offers little diversification advantage.
